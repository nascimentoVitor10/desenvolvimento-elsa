# %%
import pandas as pd
import polars as pl
import sys
from openpyxl import load_workbook
from pathlib import Path

# %%
# Caminhos das bases da onda 1

lista_dirs1={
'base01_completa'    : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - COMPLETA\O1.xlsx",
'laboratorio'        : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Laboratório Onda 1\base_lab_onda1_151120.dta" ,
'labSI'              : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Laboratório Onda 1\Base Laboratório Sistema Internacional Onda 1\base_LAB_SI_onda1_151120.dta",
'medContinua_pa'     : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Medicamentos Onda 1\Continuo\base_med_o1_c_pa_150619.dta",
'medContinua_p1'     : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Medicamentos Onda 1\Continuo\base_med_o1_c_150619_parte1.dta",
'medContinua_p2'     : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Medicamentos Onda 1\Continuo\base_med_o1_c_150619_parte2.dta",
'medContinua_p3'     : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Medicamentos Onda 1\Continuo\base_med_o1_c_150619_parte3.dta",
'dieta'              : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Dieta Onda 1\base_dieta_onda1_150619.dta",
'der_sindr_met'      : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1_Base Derivadas_Síndrome Metabólica_JUL2015\base_derivadas_090715.xlsx",
'hemograma'          : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Hemograma Onda1\Base_Hemograma_onda1_150619.dta",
'georeferenciamento' : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Geo Onda 1 Nova\Base_Geo_onda1_150619.dta",
'ocupação'           : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Ocupação Onda 1\base_ocupacao_150619_idelsa.dta",
'ultraprocessadps'   : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Ultraprocessados onda 1\base_var_ultraprocessados_140319.dta"
}

# %%
lista_dirs2={
'base02_completa': r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O2 - Base Completa Onda 2 Nova\base_elsa_onda2_150619.dta",
'bioimpd'        : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O2 - Base Bioimpedancia Onda 2\base_bio_onda2_150619_dist.dta",
'lab'            : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O1 - Base Laboratório Onda 2\base_lab_onda2_151120.dta",
'labSI'          : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O1 - Base Laboratório Onda 2\Base Laboratório Sistema Internacional Onda 2\base_LAB_SI_onda2_151120.dta",
'medClasses'     : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O2 - Base Medicamentos Onda 2\Classes\BASE_MED_O2_150619_DIST.dta",
'medConcent_A_C' : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O2 - Base Medicamentos Onda 2\Concentracao\MED_O2_CON_A_C_DIST_150619.dta",
'medConcent_D_K' : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O2 - Base Medicamentos Onda 2\Concentracao\MED_O2_CON_D_K_DIST_150619.dta",
'medConcent_L_P' : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O2 - Base Medicamentos Onda 2\Concentracao\MED_O2_CON_L_P_DIST_150619.dta",
'medConcent_Q_Z' : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 2\O2 - Base Medicamentos Onda 2\Concentracao\MED_O2_CON_Q_Z_DIST_150619.dta" ,
'hemo'           : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Dieta Onda 1\base_dieta_onda1_150619.dta",
'PCR'            : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1_Base Derivadas_Síndrome Metabólica_JUL2015\base_derivadas_090715.xlsx",
'RETCL'          : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Hemograma Onda1\Base_Hemograma_onda1_150619.dta",
'recusa_obito'   : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Geo Onda 1 Nova\Base_Geo_onda1_150619.dta",
'derivadas'      : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Ultraprocessados onda 1\base_var_ultraprocessados_140319.dta"
}

# %%
lista_dirs3={
'base01_completa': r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - COMPLETA\O1.xlsx",
'lab'            : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Laboratório Onda 1\base_lab_onda1_151120.dta" ,
'labSI'          : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Laboratório Onda 1\Base Laboratório Sistema Internacional Onda 1\base_LAB_SI_onda1_151120.dta",
'medCont_p1'     : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Medicamentos Onda 1\Continuo\base_med_o1_c_150619_parte1.dta",
'medCont_p2'     : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Medicamentos Onda 1\Continuo\base_med_o1_c_150619_parte2.dta",
'medCont_p3'     : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Medicamentos Onda 1\Continuo\base_med_o1_c_150619_parte3.dta",
'dieta'          : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Dieta Onda 1\base_dieta_onda1_150619.dta",
'der_dieta'      : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1_Base Derivadas_Síndrome Metabólica_JUL2015\base_derivadas_090715.xlsx",
'hemo'           : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Hemograma Onda1\Base_Hemograma_onda1_150619.dta",
'geo'            : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Geo Onda 1 Nova\Base_Geo_onda1_150619.dta",
'ocup'           : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Base Ocupação Onda 1\base_ocupacao_150619_idelsa.dta",
'ultrap'         : r"E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - onda 1\O1 - Ultraprocessados onda 1\base_var_ultraprocessados_140319.dta"
}

# %%
path_dict = r"E:\elsa\ELSA\Solicitações\Solicitações Vitor Ramos\Oscar Martinez\08_11_24\Dicionario_ELSA_Milena_Santos.xlsx"
df_pedido = pd.read_excel(path_dict)
df_pedido_onda1 = df_pedido.iloc[:, 0:3]
df_pedido_onda2 = df_pedido.iloc[:, 4:7]
df_pedido_onda3 = df_pedido.iloc[:, 8:11]

variaveis_pedidas_onda1 = list(set([i.strip().upper() for i in df_pedido_onda1[df_pedido_onda1['Unnamed: 1'].notnull()].iloc[1:, 1]]))
variaveis_pedidas_onda2 = list(set([i.strip().upper() for i in df_pedido_onda2[df_pedido_onda2['Unnamed: 5'].notnull()].iloc[1:, 1]]))
variaveis_pedidas_onda3 = list(set([i.strip().upper() for i in df_pedido_onda3[df_pedido_onda3['Unnamed: 9'].notnull()].iloc[1:, 1]]))

print(len(variaveis_pedidas_onda1))
print(len(variaveis_pedidas_onda2))
print(len(variaveis_pedidas_onda3))
# Out:
# 843
# 414
# 601

# %% [markdown]
# # extração de variáveis da onda 1

# %%
# ferramentas para carregamento de grandes volumes de dados

'''
1 - pandas com o carregamento por partes
2 - biblioteca dask
3 - PySpark a interfaxe do Spark para python
4 - SQLite, um sistema de gerenciamento de banco de dados
'''
# Out:
# '\n1 - pandas com o carregamento por partes\n2 - biblioteca dask\n3 - PySpark a interfaxe do Spark para python\n4 - SQLite, um sistema de gerenciamento de banco de dados\n'

# %%
# pipeline de extração de dados

# [1]
def save_vars_in_txt(vars:list, txt_file_path:str):
    """
    Essa função irá acessar o caminho do arquivo passado
    e irá preenchê-lo com as variáveis informadas para que
    elas possam ser salvas para posteriores consultas

    Parâmetros:

        vars(list)      : variáveis que ainda não foram encontradas nos dados
        file_path(str)  : caminho do arquivo .txt em que as serão salvas as variáveis 
    """
    try:
        with open(txt_file_path, 'w') as file:
            for var in vars:
                file.write(var + '\n')
            print("arquivo preenchido!")
    
    except IOError:
        print("arquivo não encontrado")



# [2]
def load_list_txt(txt_file_path:str)->list:
    """
    Retorna uma lista python das variáveis salvas no arquivo .txt

    Parâmetros:
        file_path: caminho do arquivo em que as variáveis estão armazenadas
    """
    vars = []
    with open(txt_file_path, 'r') as file:
        for line in file:
            if "\n" in line:
                line = line.replace('\n','')
                vars.append((line.strip()).upper())
    return vars



# [3]
def get_columns_var_excel_file(file_path:str)->list:
    """
    Retorna uma lista de variáveis que compõem as colunas de um arquivo .xslx,
    pois os arquivos excel são mais trabalhosos para serem carregados quando
    muito grandes.

    Parâmetros:
        file_path: caminho do arquivo .xslx a ser analisado

    """
    vars = []
    workbook = load_workbook(filename=file_path, read_only=True)
    worksheet = workbook.active

    for row in worksheet.iter_rows(min_row=1, max_row=1, values_only=True):
        vars = [i.upper() for i in row]

    return vars



# [4]
def compare_lists(df_vars:list, txt_vars:list)->tuple:
    """
    Retorna uma lista de variáveis que estão presentes no dataframe e
    atualiza o arquivo .txt em que as variáveis não encontradas no 
    dataframe ficam armazenadas.

    Parâmetros:
        df_vars(list) : lista de variáveis que compõem as colunas do dataframe
        txt_vars(list): lista das variáveis presentes no arquivo .txt
    """
    txt_file_path = r'E:\elsa\ELSA\desenvolvimento-elsa\scripts\elsa_organizacao_bases\dados_extracao\vars_n_encontradas.txt'
    if 'IDELSA' not in txt_vars:
            txt_vars.insert(0, 'IDELSA')

    variaveis_encontradas_df = [i for i in txt_vars if i in df_vars]
    variaveis_Nencontradas_df = [i for i in txt_vars if i not in df_vars]

    save_vars_in_txt(variaveis_Nencontradas_df, txt_file_path)
    return variaveis_encontradas_df



def save_df(df:pd.DataFrame, id:str, path_file:str):
    df.to_excel(path_file)
    print(f'df_{id} : salvo')
    print(f'    rows:{df.shape[0]} -- cols:{df.shape[1]}\n')
    del df


# [5]
def load_large_dta(file_path:str, txt_file_path:str) -> pd.DataFrame:
    """
    Retorna dataframe correspondente ao caminho de arquivo .dta informado

    Parâmetros:
        file_path: caminho do arquivo .dta a ser analisado
    """
    reader = pd.read_stata(file_path, iterator=True)
    df = pd.DataFrame()
    try:
        chunk = reader.get_chunk(100*1000)
        while len(chunk) > 0:
            df = pd.concat([df,chunk], ignore_index=True)
            chunk = reader.get_chunk(100*1000)
            sys.stdout.flush()
    except (StopIteration, KeyboardInterrupt):
        pass

    df_columns_upper = [i.upper() for i in df.columns]
    df.columns = df_columns_upper

    vars_in_txt = load_list_txt(txt_file_path=txt_file_path)
    vars_in_df= compare_lists(list(df.columns), vars_in_txt)
    
    if len(vars_in_df) <= 1:
        print("Nenhuma variável encontrada nessa base.")
        return pd.DataFrame(None)

    return df[vars_in_df].sort_values(by='IDELSA', ascending=True)



# [6]
def load_large_excel(file_path:str, txt_file_path:str) -> pd.DataFrame:
    """
    Retorna o dataframe do arquivo .xslx já filtrado com as variáveis encontradas

    Parâmetros:

        file_path    : caminho do arquivo .xslx a ser analisado
        txt_file_path: caminho do arquivo .txt em que as variáveis ficam armazenadas
    """
    vars_df = get_columns_var_excel_file(file_path=file_path)
    vars_file_txt = load_list_txt(txt_file_path=txt_file_path)
    vars_in_df= compare_lists(vars_df, vars_file_txt)

    if len(vars_in_df) <= 1:
        print("Nenhuma variável encontrada nessa base.")
        return pd.DataFrame(None)

    df_filtrado = pd.read_excel(file_path, engine='calamine', usecols=vars_in_df)
    return df_filtrado.sort_values(by='IDELSA', ascending=True)

# %%
txt_file_path = r'E:\elsa\ELSA\desenvolvimento-elsa\scripts\elsa_organizacao_bases\dados_extracao\vars_n_encontradas.txt'
save_vars_in_txt(vars=variaveis_pedidas_onda1, txt_file_path=txt_file_path)
with pd.ExcelWriter(r'E:\elsa\ELSA\desenvolvimento-elsa\scripts\elsa_organizacao_bases\dados_extracao\onda1\extracao_onda1.xlsx', engine='xlsxwriter') as writer:

    for idx, base in enumerate(lista_dirs1):

        if lista_dirs1[base].endswith('.dta'):
            df = load_large_dta(file_path=lista_dirs1[base], txt_file_path=txt_file_path)
        
        else:
            df = load_large_excel(file_path=lista_dirs1[base], txt_file_path=txt_file_path)
        
        df.to_excel(writer, sheet_name=base + f" tabela {idx + 1}")
        del df
# Out:
# arquivo preenchido!
# arquivo preenchido!
# df : Index(['IDELSA', 'LABA1_3', 'LABA2_3', 'LABA3_R_3', 'LABA4', 'LABA5', 'LABA6',
#        'LABA7', 'LABA8', 'LABA9', 'LABA10_3', 'LABA11_3', 'LABA12_3',
#        'LABA13_3', 'LABA14_CARGA', 'LABA14_TTG_3', 'LABA15', 'LABA16_R_2',
#        'LABA17', 'LABA18', 'LABA19MCGMIN', 'LABA19MGDL', 'LABA20', 'LABA21',
#        'LABA22_3', 'LABA23_3', 'LABA24', 'LABA25', 'LABA28', 'A_VOL_URINA',
#        'A_TEMPO_COL_MIN', 'A_RAC_R_2', 'A_FLUXO_UR', 'A_CREAT_TOTAL_R_2',
#        'A_CREAT_KG_R_2', 'A_NA_K', 'A_NA_TOT', 'A_K_TOT', 'A_CREAT_AJ12H_R_2',
#        'A_CREAT_AJ12H_KG_R_2', 'A_NA_AJ12H', 'A_K_AJ12H', 'A_CL_CREAT_R_2',
#        'A_SUPERF_CORPORAL', 'A_CL_CREAT_173_R_2', 'A_CREAT_EST24H_R_2',
#        'A_NA_EST24H', 'A_K_EST24H', 'A_CONS_EST_NACL', 'A_CA_TOT',
#        'A_NA_CREAT_AJ12H_R_2', 'A_K_CREAT_AJ12H_R_2', 'A_VALID_VOL_URINA',
#        'A_VALID_TEM_COL_URINA', 'A_VALID_CREAT_AJ_R_2', 'A_VALID_URINA_R_2',
#        'A_TEMPO_JEJUM', 'A_CKDEPI_R_3', 'A_CKDEPI_R_CAT_2', 'A_TSH_ROCHE',
#        'A_T3LIVRE_ROCHE', 'A_T4LIVRE_ROCHE', 'A_ANTI_TPO_ROCHE'],
#       dtype='object')
# arquivo preenchido!
# df : Index(['IDELSA', 'A_LABA1_3', 'A_LABA2_MMOLMOL', 'A_LABA3_R_2', 'A_LABA4',
#        'A_LABA5', 'A_LABA6UL', 'A_LABA6_MCKAT_2', 'A_LABA7UL',
#        'A_LABA7_MCKAT_2', 'A_LABA8UL', 'A_LABA8_MCKAT_2', 'A_LABA9_2',
#        'A_LABA10_3', 'A_LABA11_3', 'A_LABA12_3', 'A_LABA13_3',
#        'A_LABA14_CARGA_2', 'A_LABA14_3', 'A_LABA15_2', 'A_LABA16_R_2',
#        'A_LABA17', 'A_LABA18', 'A_LABA19MCGMIN', 'A_LABA19MGDL', 'A_LABA20',
#        'A_LABA21_2', 'A_LABA22_3', 'A_LABA23_3', 'A_LABA25_2', 'A_LABA28_2'],
#       dtype='object')
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'ALGUM_TIPO_DE_MED_', 'USO_CONTINUO', 'TOMA_DIUR_TICOS',
#        'TOMA_BLOQUEADORES_DE_RECEPTORES_', 'TOMA_INIBIDORES_DA_ECA',
#        'TOMA_BLOQUEADORES_DE_CANAL_DE_C_', 'TOMA_BETABLOQUEADORES',
#        'TOMA_OUTROS_ANTI_HIPERTENSIVOS', 'TOMA_ANTI_HIPERTENSIVOS',
#        ...
#        'FAZ_USO_CONT_NUO_DE_VILDAGLIPTIN', 'FAZ_USO_CONT_NUO_DE_VIMPOCETINA',
#        'FAZ_USO_CONT_NUO_DE_VITAMINA_A', 'FAZ_USO_CONT_NUO_DE_VITAMINA_E',
#        'FAZ_USO_CONT_NUO_DE_XILOMETAZOLI', 'FAZ_USO_CONT_NUO_DE_ZEAXANTINA',
#        'FAZ_USO_CONT_NUO_DE_ZIDOVUDINA', 'FAZ_USO_CONT_NUO_DE_ZIPRASIDONA',
#        'FAZ_USO_CONT_NUO_DE_ZOLPIDEM', 'FAZ_USO_CONT_NUO_DE_ZOPICLONA'],
#       dtype='object', length=759)
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'CONCENTRA__O_DE_ABATACEPTE',
#        'UNIDADE_DA_CONCENTRA__O_DE_ABATA', 'FORMA_FARMAC_UTICA_DE_ABATACEPTE',
#        'ESPECIFIQUE_FORM_FARM_DE_ABATACE', 'RECEITA__DE_ABATACEPTE',
#        'EMBALAGEM_CARTELA_OU_BULA__DE_AB', 'PRESCRITO_POR_M_DICO_OU_DENTISTA',
#        'RECEITA__UN__DE_ABATACEPTE', 'RECEITA__NO_POR_VEZ__DE_ABATACEP',
#        ...
#        'TOMOU_MED___UN__DE_DIAZEPAM', 'TOMOU_MED___NO_POR_VEZ__DE_DIAZE',
#        'TOMOU_MED___UN__DE_DIAZEPAM_1', 'TOMOU_MED___LTIMAS_DUAS_SEM__249',
#        'TEMPO__ANOS__DE_DIAZEPAM', 'TEMPO__MESES__DE_DIAZEPAM',
#        'TEMPO__DIAS__DE_DIAZEPAM', 'CLASSIFICA__O_ATC_OMS_DE_DIAZEPA',
#        'DOSE_DIARIA_31', 'TEMPO_DE_USO_EM_ANOS_31'],
#       dtype='object', length=4565)
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'CONCENTRA__O_DE_DICLOFENACO',
#        'UNIDADE_DA_CONCENTRA__O_DE_DICLO', 'FORMA_FARMAC_UTICA_DE_DICLOFENAC',
#        'ESPECIFIQUE_FORM_FARM_DE_DICLOFE', 'RECEITA__DE_DICLOFENACO',
#        'EMBALAGEM__CARTELA_OU_BULA__DE_D', 'PRESCRITO_POR_M_DICO_OU_DENTISTA',
#        'RECEITA__UN__DE_DICLOFENACO', 'RECEITA__NO_POR_VEZ__DE_DICLOFEN',
#        ...
#        'TOMOU_MED___UN__DE_MIRTAZAPINA', 'TOMOU_MED___NO_POR_VEZ__DE_MIRTA',
#        'TOMOU_MED___UN__DE_MIRTAZAPINA_1', 'TOMOU_MED___LTIMAS_DUAS_SEM__247',
#        'TEMPO__ANOS__DE_MIRTAZAPINA', 'TEMPO__MESES__DE_MIRTAZAPINA',
#        'TEMPO__DIAS__DE_MIRTAZAPINA', 'CLASSIFICA__O_ATC_OMS_DE_MIRTAZA',
#        'DOSE_DIARIA_40', 'TEMPO_DE_USO_EM_ANOS_40'],
#       dtype='object', length=4547)
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'CONCENTRA__O_DE_MODAFINILA',
#        'UNIDADE_DA_CONCENTRA__O_DE_MODAF', 'FORMA_FARMAC_UTICA_DE_MODAFINILA',
#        'ESPECIFIQUE_FORM_FARM_DE_MODAFIN', 'RECEITA__DE_MODAFINILA',
#        'EMBALAGEM__CARTELA_OU_BULA__DE_M', 'PRESCRITO_POR_M_DICO_OU_DENTISTA',
#        'RECEITA__UN__DE_MODAFINILA', 'RECEITA__NO_POR_VEZ__DE_MODAFINI',
#        ...
#        'RECEITA__NO_POR_VEZ__DE_ZOPICLON', 'RECEITA__UM__DE_ZOPICLONA',
#        'TOMOU_MED___UN__DE_ZOPICLONA', 'TOMOU_MED___NO_POR_VEZ__DE_ZOPIC',
#        'TOMOU_MED___UN__DE_ZOPICLONA_1', 'TOMOU_MED___LTIMAS_DUAS_SEM__246',
#        'TEMPO__ANOS__DE_ZOPICLONA', 'TEMPO__MESES__DE_ZOPICLONA',
#        'TEMPO__DIAS__DE_ZOPICLONA', 'CLASSIFICA__O_ATC_OMS_DE_ZOPICLO'],
#       dtype='object', length=4509)
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'DIEA1F', 'DIEA1T', 'DIEA1Q', 'DIEA1S', 'DIEA2F', 'DIEA2Q',
#        'DIEA2S', 'DIEA3F', 'DIEA3Q',
#        ...
#        'A_SOMA_GRUPOS', 'A_INCONSISTENCIA_CARNE', 'A_INCONSISTENCIA_FRANGO',
#        'A_INCONSISTENCIA_DOCES', 'A_SOMA_FASTFOOD', 'A_SOMA_FRUTAS',
#        'A_SOMA_VEGETAIS', 'A_RAZAO_FASTFOOD', 'A_RAZAO_FRUTAS',
#        'A_RAZAO_VEGETAIS'],
#       dtype='object', length=3777)
# arquivo preenchido!
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'LABA26A', 'LABA26B', 'LABA26D', 'LABA26F', 'LABA26G',
#        'LABA26I', 'LABA26K', 'LABA26N', 'LABA26R_P', 'LABA26R_N', 'LABA26S_P',
#        'LABA26S_N', 'LABA26T_P', 'LABA26T_N', 'LABA26U_P', 'LABA26U_N',
#        'LABA26V_P', 'LABA26V_N', 'LABA26W_P', 'LABA26W_N', 'LABA26X_P',
#        'LABA26X_N', 'LABA26Y_P', 'LABA26Y_N', 'LABA26Z'],
#       dtype='object')
# arquivo preenchido!
# df : Index(['IDELSA', 'CENTROA', 'A_GEOCODVIZ', 'A_GEOCODBAIRRO',
#        'A_GEOCODMUNESCOLA', 'A_GEOCODMUNNASC', 'A_GEONOMEBAIRRO',
#        'A_GEONOMEMUNESCOLA', 'A_GEONOMEMUNNASC', 'A_GEOSETORCENSO',
#        'A_GEOMUNICIPIOATUAL', 'A_GEOCODMUNIBGEATUAL'],
#       dtype='object')
# arquivo preenchido!
# df : Index(['IDENTIFICADOR_BASE_ELSA', 'OCUPA__O_TODOS', 'OCUPA__O_ATIVOS',
#        'OCUPA__O_INATIVOS'],
#       dtype='object')
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'A_GRUPO1CAL', 'A_GRUPO2CAL', 'A_GRUPO3CAL', 'A_GRUPO1G',
#        'A_GRUPO2G', 'A_GRUPO3G'],
#       dtype='object')
# arquivo preenchido!

# %%
import openpyxl
import os



txt_file_path = r'/scripts/elsa_organizacao_bases/dados_extracao/vars_pedidas.txt'
save_vars_in_txt(vars=variaveis_pedidas_onda3, txt_file_path=txt_file_path)

with pd.ExcelWriter(r'E:\elsa\ELSA\desenvolvimento-elsa\scripts\elsa_organizacao_bases\dados_extracao\onda3\extracao_onda3.xlsx', engine='xlsxwriter') as writer:

    for idx, base in enumerate(lista_dirs3):

        if lista_dirs3[base].endswith('.dta'):
            df = load_large_dta(file_path=lista_dirs3[base], txt_file_path=txt_file_path)
        
        else:
            df = load_large_excel(file_path=lista_dirs3[base], txt_file_path=txt_file_path)
        
        df.to_excel(writer, sheet_name=base + f"- tabela {idx + 1}")
        del df
# Out:
# arquivo preenchido!
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'LABA1_3', 'LABA2_3', 'LABA3_R_3', 'LABA4', 'LABA5', 'LABA6',
#        'LABA7', 'LABA8', 'LABA9', 'LABA10_3', 'LABA11_3', 'LABA12_3',
#        'LABA13_3', 'LABA14_CARGA', 'LABA14_TTG_3', 'LABA15', 'LABA16_R_2',
#        'LABA17', 'LABA18', 'LABA19MCGMIN', 'LABA19MGDL', 'LABA20', 'LABA21',
#        'LABA22_3', 'LABA23_3', 'LABA24', 'LABA25', 'LABA28', 'A_VOL_URINA',
#        'A_TEMPO_COL_MIN', 'A_RAC_R_2', 'A_FLUXO_UR', 'A_CREAT_TOTAL_R_2',
#        'A_CREAT_KG_R_2', 'A_NA_K', 'A_NA_TOT', 'A_K_TOT', 'A_CREAT_AJ12H_R_2',
#        'A_CREAT_AJ12H_KG_R_2', 'A_NA_AJ12H', 'A_K_AJ12H', 'A_CL_CREAT_R_2',
#        'A_SUPERF_CORPORAL', 'A_CL_CREAT_173_R_2', 'A_CREAT_EST24H_R_2',
#        'A_NA_EST24H', 'A_K_EST24H', 'A_CONS_EST_NACL', 'A_CA_TOT',
#        'A_NA_CREAT_AJ12H_R_2', 'A_K_CREAT_AJ12H_R_2', 'A_VALID_VOL_URINA',
#        'A_VALID_TEM_COL_URINA', 'A_VALID_CREAT_AJ_R_2', 'A_VALID_URINA_R_2',
#        'A_TEMPO_JEJUM', 'A_CKDEPI_R_3', 'A_CKDEPI_R_CAT_2', 'A_TSH_ROCHE',
#        'A_T3LIVRE_ROCHE', 'A_T4LIVRE_ROCHE', 'A_ANTI_TPO_ROCHE'],
#       dtype='object')
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'A_LABA1_3', 'A_LABA2_MMOLMOL', 'A_LABA3_R_2', 'A_LABA4',
#        'A_LABA5', 'A_LABA6UL', 'A_LABA6_MCKAT_2', 'A_LABA7UL',
#        'A_LABA7_MCKAT_2', 'A_LABA8UL', 'A_LABA8_MCKAT_2', 'A_LABA9_2',
#        'A_LABA10_3', 'A_LABA11_3', 'A_LABA12_3', 'A_LABA13_3',
#        'A_LABA14_CARGA_2', 'A_LABA14_3', 'A_LABA15_2', 'A_LABA16_R_2',
#        'A_LABA17', 'A_LABA18', 'A_LABA19MCGMIN', 'A_LABA19MGDL', 'A_LABA20',
#        'A_LABA21_2', 'A_LABA22_3', 'A_LABA23_3', 'A_LABA25_2', 'A_LABA28_2'],
#       dtype='object')
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'CONCENTRA__O_DE_ABATACEPTE',
#        'UNIDADE_DA_CONCENTRA__O_DE_ABATA', 'FORMA_FARMAC_UTICA_DE_ABATACEPTE',
#        'ESPECIFIQUE_FORM_FARM_DE_ABATACE', 'RECEITA__DE_ABATACEPTE',
#        'EMBALAGEM_CARTELA_OU_BULA__DE_AB', 'PRESCRITO_POR_M_DICO_OU_DENTISTA',
#        'RECEITA__UN__DE_ABATACEPTE', 'RECEITA__NO_POR_VEZ__DE_ABATACEP',
#        ...
#        'TOMOU_MED___UN__DE_DIAZEPAM', 'TOMOU_MED___NO_POR_VEZ__DE_DIAZE',
#        'TOMOU_MED___UN__DE_DIAZEPAM_1', 'TOMOU_MED___LTIMAS_DUAS_SEM__249',
#        'TEMPO__ANOS__DE_DIAZEPAM', 'TEMPO__MESES__DE_DIAZEPAM',
#        'TEMPO__DIAS__DE_DIAZEPAM', 'CLASSIFICA__O_ATC_OMS_DE_DIAZEPA',
#        'DOSE_DIARIA_31', 'TEMPO_DE_USO_EM_ANOS_31'],
#       dtype='object', length=4565)
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'CONCENTRA__O_DE_DICLOFENACO',
#        'UNIDADE_DA_CONCENTRA__O_DE_DICLO', 'FORMA_FARMAC_UTICA_DE_DICLOFENAC',
#        'ESPECIFIQUE_FORM_FARM_DE_DICLOFE', 'RECEITA__DE_DICLOFENACO',
#        'EMBALAGEM__CARTELA_OU_BULA__DE_D', 'PRESCRITO_POR_M_DICO_OU_DENTISTA',
#        'RECEITA__UN__DE_DICLOFENACO', 'RECEITA__NO_POR_VEZ__DE_DICLOFEN',
#        ...
#        'TOMOU_MED___UN__DE_MIRTAZAPINA', 'TOMOU_MED___NO_POR_VEZ__DE_MIRTA',
#        'TOMOU_MED___UN__DE_MIRTAZAPINA_1', 'TOMOU_MED___LTIMAS_DUAS_SEM__247',
#        'TEMPO__ANOS__DE_MIRTAZAPINA', 'TEMPO__MESES__DE_MIRTAZAPINA',
#        'TEMPO__DIAS__DE_MIRTAZAPINA', 'CLASSIFICA__O_ATC_OMS_DE_MIRTAZA',
#        'DOSE_DIARIA_40', 'TEMPO_DE_USO_EM_ANOS_40'],
#       dtype='object', length=4547)
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'CONCENTRA__O_DE_MODAFINILA',
#        'UNIDADE_DA_CONCENTRA__O_DE_MODAF', 'FORMA_FARMAC_UTICA_DE_MODAFINILA',
#        'ESPECIFIQUE_FORM_FARM_DE_MODAFIN', 'RECEITA__DE_MODAFINILA',
#        'EMBALAGEM__CARTELA_OU_BULA__DE_M', 'PRESCRITO_POR_M_DICO_OU_DENTISTA',
#        'RECEITA__UN__DE_MODAFINILA', 'RECEITA__NO_POR_VEZ__DE_MODAFINI',
#        ...
#        'RECEITA__NO_POR_VEZ__DE_ZOPICLON', 'RECEITA__UM__DE_ZOPICLONA',
#        'TOMOU_MED___UN__DE_ZOPICLONA', 'TOMOU_MED___NO_POR_VEZ__DE_ZOPIC',
#        'TOMOU_MED___UN__DE_ZOPICLONA_1', 'TOMOU_MED___LTIMAS_DUAS_SEM__246',
#        'TEMPO__ANOS__DE_ZOPICLONA', 'TEMPO__MESES__DE_ZOPICLONA',
#        'TEMPO__DIAS__DE_ZOPICLONA', 'CLASSIFICA__O_ATC_OMS_DE_ZOPICLO'],
#       dtype='object', length=4509)
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'DIEA1F', 'DIEA1T', 'DIEA1Q', 'DIEA1S', 'DIEA2F', 'DIEA2Q',
#        'DIEA2S', 'DIEA3F', 'DIEA3Q',
#        ...
#        'A_SOMA_GRUPOS', 'A_INCONSISTENCIA_CARNE', 'A_INCONSISTENCIA_FRANGO',
#        'A_INCONSISTENCIA_DOCES', 'A_SOMA_FASTFOOD', 'A_SOMA_FRUTAS',
#        'A_SOMA_VEGETAIS', 'A_RAZAO_FASTFOOD', 'A_RAZAO_FRUTAS',
#        'A_RAZAO_VEGETAIS'],
#       dtype='object', length=3777)
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.
# arquivo preenchido!
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'LABA26A', 'LABA26B', 'LABA26D', 'LABA26F', 'LABA26G',
#        'LABA26I', 'LABA26K', 'LABA26N', 'LABA26R_P', 'LABA26R_N', 'LABA26S_P',
#        'LABA26S_N', 'LABA26T_P', 'LABA26T_N', 'LABA26U_P', 'LABA26U_N',
#        'LABA26V_P', 'LABA26V_N', 'LABA26W_P', 'LABA26W_N', 'LABA26X_P',
#        'LABA26X_N', 'LABA26Y_P', 'LABA26Y_N', 'LABA26Z'],
#       dtype='object')
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'CENTROA', 'A_GEOCODVIZ', 'A_GEOCODBAIRRO',
#        'A_GEOCODMUNESCOLA', 'A_GEOCODMUNNASC', 'A_GEONOMEBAIRRO',
#        'A_GEONOMEMUNESCOLA', 'A_GEONOMEMUNNASC', 'A_GEOSETORCENSO',
#        'A_GEOMUNICIPIOATUAL', 'A_GEOCODMUNIBGEATUAL'],
#       dtype='object')
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.
# df : Index(['IDENTIFICADOR_BASE_ELSA', 'OCUPA__O_TODOS', 'OCUPA__O_ATIVOS',
#        'OCUPA__O_INATIVOS'],
#       dtype='object')
# arquivo preenchido!
# encontradas :[]
# Nenhuma variável encontrada nessa base.
# df : Index(['IDELSA', 'A_GRUPO1CAL', 'A_GRUPO2CAL', 'A_GRUPO3CAL', 'A_GRUPO1G',
#        'A_GRUPO2G', 'A_GRUPO3G'],
#       dtype='object')
# arquivo preenchido!
# encontradas :['IDELSA']
# Nenhuma variável encontrada nessa base.

# %%
import os

caminho = r"E:\elsa\ELSA\desenvolvimento-elsa\scripts\elsa_organizacao_bases\dados_extracao\onda3\extracao_onda3.xlsx"

if os.path.exists(caminho) and os.access(caminho, os.R_OK):
    df = pd.read_excel(caminho, engine='calamine')

df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
"""
1 - tenho a lista de variaveis solicitadas
2 - salvo essas variaveis em um arquivo .txt 
3 - carrego em em uma lista python  
3 - tenho a lista das variaveis presentes no dataset analisado 
4 - função para comparar as duas listas e retornar as encontradas e as não encontradas
5 - as não encontradas salvo no arquivo antes criado e retorno a lista das encontradas
6 - carrego somente as colunas das variaveis encontradas
7 - salvo esse dataframe separadamente
"""
# Out:
# '\n1 - tenho a lista de variaveis solicitadas\n2 - salvo essas variaveis em um arquivo .txt \n3 - carrego em em uma lista python  \n3 - tenho a lista das variaveis presentes no dataset analisado \n4 - função para comparar as duas listas e retornar as encontradas e as não encontradas\n5 - as não encontradas salvo no arquivo antes criado e retorno a lista das encontradas\n6 - carrego somente as colunas das variaveis encontradas\n7 - salvo esse dataframe separadamente\n'

# %%
df = pd.read_stata("E:\elsa\ELSA\Bases de dados\Base Elsa\Bases - multíplas ondas\O1O2 - Base Derivadas de Diabetes Onda 1 e Onda 2\incdm2016_idelsa_100117.dta")
df = df.sort_
# Out:
#       identificador_base_elsa  primeira_defini__o_diabetes_onda  \
# 0                      1000SP                               1.0
# 1                      1001SP                               0.0
# 2                      1002SP                               0.0
# 3                      1003SP                               0.0
# 4                      1004SP                               0.0
# ...                       ...                               ...
# 15100                  3326BA                               0.0
# 15101                  3327BA                               0.0
# 15102                  3328BA                               0.0
# 15103                  3329BA                               0.0
# 15104                  3331BA                               0.0
#
#        primeira_defini__o_diabetes_ond1  incid_ncia_diabetes_primeira_def  \
# 0                                   1.0                               NaN
# 1                                   0.0                               0.0
# 2                                   1.0                               NaN
# 3                                   0.0                               0.0
# 4                                   0.0                               0.0
# ...                                 ...                               ...
# 15100                               0.0                               0.0
# 15101                               0.0                               0.0
# 15102                               0.0                               0.0
# 15103                               0.0                               0.0
# 15104                               0.0                               0.0
#
#        incdm__autorreferido_na_onda_2  incdm__uso_de_medica__o_na_onda_  \
# 0                                 NaN                               NaN
# 1                                 0.0                               0.0
# 2                                 NaN                               NaN
# 3                                 0.0                               0.0
# 4                                 0.0                               0.0
# ...                               ...                               ...
# 15100                             0.0                               0.0
# 15101                             0.0                               0.0
# 15102                             0.0                               0.0
# 15103                             0.0                               0.0
# 15104                             0.0                               0.0
#
#        incdm__altera__o_lab_na_onda_2  censura_incdm__motivo_para_censu  \
# 0                                 NaN                               NaN
# 1                                 0.0                               1.0
# 2                                 NaN                               NaN
# 3                                 0.0                               1.0
# 4                                 0.0                               1.0
# ...                               ...                               ...
# 15100                             0.0                               1.0
# 15101                             0.0                               1.0
# 15102                             0.0                               1.0
# 15103                             0.0                               1.0
# 15104                             0.0                               1.0
#
#       data_de_evento_censura_primeira_  dias_at__incid_ncia_diabetes_pri
# 0                                  NaT                               NaN
# 1                           2013-09-26                            1533.0
# 2                                  NaT                               NaN
# 3                           2014-01-30                            1505.0
# 4                           2014-05-27                            1729.0
# ...                                ...                               ...
# 15100                       2014-09-01                            1447.0
# 15101                       2014-09-26                            1484.0
# 15102                       2014-10-30                            1484.0
# 15103                       2014-08-25                            1441.0
# 15104                       2014-08-15                            1425.0
#
# [15105 rows x 10 columns]
